# %%
import winsound
import matplotlib.pyplot as plt
import numpy as np
from skimage import morphology as mp
import cv2
from operator import itemgetter

# %%
frequency = 2500
duration = 1000

# %%
winsound.Beep(frequency, duration)

# %%
twinkle = cv2.imread("Twinkle_Twinkle_Sheet_Music.png")
twinkle = cv2.cvtColor(twinkle, cv2.COLOR_BGR2GRAY)
s1 = cv2.imread("s1.jpg")
s1 = cv2.cvtColor(s1, cv2.COLOR_BGR2GRAY)
s2 = cv2.imread("s2.jpg")
s2 = cv2.cvtColor(s2, cv2.COLOR_BGR2GRAY)
t1 = cv2.imread("template_1.png")
t1 = cv2.cvtColor(t1, cv2.COLOR_BGR2GRAY)
t2 = cv2.imread("template_2.png")
t2 = cv2.cvtColor(t2, cv2.COLOR_BGR2GRAY)
t3 = cv2.imread("template_3.png")
t3 = cv2.cvtColor(t3, cv2.COLOR_BGR2GRAY)

# %%
#plt.plot(loc[1], loc[0], 'r.')

# %%
#from skimage import morphology
t = 0.3
blur = cv2.GaussianBlur(src = twinkle, ksize = (11,11), sigmaX = 1)
(t, binary) = cv2.threshold(src = blur,
    thresh = t, 
    maxval = 1, 
    type = cv2.THRESH_BINARY)
notes = mp.erosion(binary,s1)
notes = (notes*255).astype('uint8')
plt.figure(figsize = [15,10])
plt.imshow(binary)

# %%
# bass = cv2.imread("all_about_that_bitch.png")
# bass = cv2.cvtColor(bass, cv2.COLOR_BGR2GRAY)

# t = 0.3
# blur = cv2.GaussianBlur(src = bass, ksize = (11,11), sigmaX = 1.3)
# (t, binary) = cv2.threshold(src = blur,
#     thresh = t, 
#     maxval = 255, 
#     type = cv2.THRESH_BINARY)
# notes = mp.erosion(binary,s1)
# notes = (notes*255).astype('uint8')
# plt.figure(figsize = [20,10])
# plt.subplot(1,2,1)
# plt.imshow(bass)
# plt.subplot(1,2,2)
# plt.imshow(binary)

# %%
# size1 = 50
# s1 = np.zeros(shape=[size1,size1])
# s1[size1//2,:] = 1

# staff = mp.dilation(bass,s1)
# #staff_sec = staff[s*shape[0]//sections:(s+1)*shape[0]//sections,:]
# #plt.figure(figsize = [20,10])
# # plt.subplot(1,2,1)
# # plt.imshow(bass)
# # plt.subplot(1,2,2)
# # plt.imshow(staff)

# plt.figure(figsize = [10,15])
# plt.imshow(staff)

# %%
def pix_to_freq_1(pix, Y):
    #freq = [698, 587, 494, 392, 330]
    # [F5,D5,B5,G4,E4]
    #freq = [1396.91, 1174.66, 987.77,783.99,659.25]
    freq_calib = [2793.83, 2349.32, 1975.53, 1567.98, 1318.51]
    z1 = np.polyfit(Y, freq_calib, 1)
    p1 = np.poly1d(z1)
    freq = pix*p1[1] + p1[0]
    return freq, p1


FREQUENCIES = []
X_COORD = []
Y_COORD = []
DURATION = []

sections = 3
image = binary
shape = image.shape

for s in range(sections):

    section = image[s*shape[0]//sections:(s+1)*shape[0]//3,:]
    ret,thresh = cv2.threshold(section.astype('uint8'),0,255,1)
    contours,hierarchy = cv2.findContours(thresh, 1, 2)
    CX, CY = [],[]
    for j in range(len(contours[:])):
        cnt = contours[j]
        M = cv2.moments(cnt)
        cx = int(M['m10']/M['m00'])
        cy = int(M['m01']/M['m00'])
        CX.append(cx)
        CY.append(cy)

    size1 = 100
    s1 = np.zeros(shape=[size1,size1])
    s1[size1//2,:] = 1

    staff = mp.dilation(twinkle,s1)
    staff_sec = staff[s*shape[0]//sections:(s+1)*shape[0]//sections,:]


    y = np.where(staff_sec[:,500] < 255)[0]
    Y = []
    for k in range(1,len(y)+1):
        if np.abs(y[k-2]-y[k-1]) > 2:
            Y.append(y[k-1])

    notes_freq = []
    duration = []
    for cy in CY:
        f, equation = pix_to_freq_1(cy, Y)
        #FREQUENCIES.append(int(f))
        notes_freq.append(int(f))
        duration.append(500)

    section_half = twinkle[s*shape[0]//sections:(s+1)*shape[0]//3,:]
    res_half = cv2.matchTemplate(section_half,t3,cv2.TM_CCOEFF_NORMED)
    plt.figure(figsize = [20,5])
    plt.imshow(res)
    plt.colorbar()
    plt.show()

    threshold = 0.78
    loc = np.where( res_half >= threshold)
    x_half = loc[1]+w/2
    y_half = loc[0]+h/2

    for y_h in y_half:
        index = y_half.tolist().index(y_h)
        f_half, equation = pix_to_freq_1(y_h, Y)
        notes_freq.append(int(f_half))
        duration.append(1000)
        CX.append(x_half[index])
        CY.append(y_half[index])
        
    indices, CX_sorted= zip(*sorted(enumerate(CX), key=itemgetter(1)))
    CY_sorted = []
    for z in indices:
        CY_sorted.append(CY[z])
        Y_COORD.append(CY[z]+s*shape[0]//sections)
        X_COORD.append(CX[z])
        FREQUENCIES.append(notes_freq[z])
        DURATION.append(duration[z])
        
    plt.figure(figsize = [20,2])
    plt.title("Staff #" + str(s+1))
    plt.imshow(section_half)
    plt.plot(CX, CY, 'ro')
 
    plt.show()
    print("Y locations of notes:" + str(CY_sorted))
    print("Calibration Curve:" + str(equation))
    #print("Note Frequencies:" + str(notes_freq))
    #print("Duration:" + str(duration))
    
plt.figure(figsize = [15,10])
plt.imshow(twinkle)
plt.plot(X_COORD, Y_COORD, 'bo')
# Out:
# Y locations of notes:[113, 113, 97, 97, 92, 92, 98.0, 101, 101, 105, 105, 109, 109, 114.0]
# Calibration Curve:
# -44.94 x + 5929
# Y locations of notes:[85, 85, 89, 89, 93, 93, 98.0, 98.0, 85, 85, 89, 89, 93, 93]
# Calibration Curve:
# -45.55 x + 5454
# Y locations of notes:[90, 90, 73, 73, 69, 69, 74.0, 77, 77, 82, 82, 86, 86, 91.0]
# Calibration Curve:
# -45.39 x + 4915

# %%
for m in range(len(FREQUENCIES)):
    winsound.Beep(FREQUENCIES[m],DURATION[m])

# %%
# pix = 113
# freq = [1396.91, 1174.66, 987.77,783.99,659.25]
# z1 = np.polyfit(Y, freq, 1)
# p1 = np.poly1d(z1)
# f = pix*p1[1] + p1[0]
# f
# Out:
# 425.3067324434119

# %%
# plt.plot(Y, freq, 'ro')
# plt.plot(Y, p1(Y), 'k')
# p1
# Out:
# poly1d([ -22.46911201, 2964.31639002])

# %%
# pix_to_freq_1(98, Y)

# %%
def pix_to_freq_1(pix, Y):
    #freq = [698, 587, 494, 392, 330]
    # [F5,D5,B5,G4,E4]
    #freq_calib = [1396.91, 1174.66, 987.77,783.99,659.25]
    freq_calib = [2793.83, 2349.32, 1975.53, 1567.98, 1318.51]
    z1 = np.polyfit(Y, freq_calib, 1)
    p1 = np.poly1d(z1)
    freq = pix*p1[1] + p1[0]
    return freq, p1


FREQUENCIES = []
X_COORD = []
Y_COORD = []
DURATION = []

s = 1
section = image[s*shape[0]//sections:(s+1)*shape[0]//3,:]
ret,thresh = cv2.threshold(section.astype('uint8'),0,255,1)
contours,hierarchy = cv2.findContours(thresh, 1, 2)
CX, CY = [],[]
for j in range(len(contours[:])):
    cnt = contours[j]
    M = cv2.moments(cnt)
    cx = int(M['m10']/M['m00'])
    cy = int(M['m01']/M['m00'])
    CX.append(cx)
    CY.append(cy)

size1 = 100
s1 = np.zeros(shape=[size1,size1])
s1[size1//2,:] = 1

staff = mp.dilation(twinkle,s1)
staff_sec = staff[s*shape[0]//sections:(s+1)*shape[0]//sections,:]


y = np.where(staff_sec[:,500] < 255)[0]
Y = []
for k in range(1,len(y)+1):
    if np.abs(y[k-2]-y[k-1]) > 2:
        Y.append(y[k-1])

notes_freq = []
duration = []
for cy in CY:
    f, equation = pix_to_freq_1(cy, Y)
    #FREQUENCIES.append(int(f))
    notes_freq.append(int(f))
    duration.append(500)

section_half = twinkle[s*shape[0]//sections:(s+1)*shape[0]//3,:]
res_half = cv2.matchTemplate(section_half,t3,cv2.TM_CCOEFF_NORMED)
plt.figure(figsize = [20,5])
plt.imshow(res_half)
plt.colorbar()
plt.show()

threshold = 0.78
loc = np.where( res_half >= threshold)
x_half = loc[1]+w/2
y_half = loc[0]+h/2

print(x_half, y_half)

for y_h in y_half:
    index = y_half.tolist().index(y_h)
    f_half, equation = pix_to_freq_1(y_h, Y)
    notes_freq.append(int(f_half))
    duration.append(1000)
    CX.append(x_half[index])
    CY.append(y_half[index])

indices, CX_sorted= zip(*sorted(enumerate(CX), key=itemgetter(1)))
CY_sorted = []
for z in indices:
    CY_sorted.append(CY[z])
    Y_COORD.append(CY[z]+s*shape[0]//sections)
    X_COORD.append(CX[z])
    FREQUENCIES.append(notes_freq[z])
    DURATION.append(duration[z])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-cfad64e02598> in <module>()
#      16
#      17 s = 1
# ---> 18 section = image[s*shape[0]//sections:(s+1)*shape[0]//3,:]
#      19 ret,thresh = cv2.threshold(section.astype('uint8'),0,255,1)
#      20 contours,hierarchy = cv2.findContours(thresh, 1, 2)
#
# NameError: name 'image' is not defined

# %%
CX, x_half
# Out:
# ([775, 724, 341, 289, 649, 598, 215, 163, 547, 496, 113, 61, 393.5, 393.5],
#  array([393.5, 828.5]))

# %%
X_COORD, Y_COORD, FREQUENCIES, DURATION
# Out:
# ([61, 113, 163, 215, 289, 341, 393.5, 393.5, 496, 547, 598, 649, 724, 775],
#  [215, 215, 219, 219, 223, 223, 228.0, 228.0, 215, 215, 219, 219, 223, 223],
#  [1581,
#   1581,
#   1399,
#   1399,
#   1217,
#   1217,
#   989,
#   989,
#   1581,
#   1581,
#   1399,
#   1399,
#   1217,
#   1217],
#  [500, 500, 500, 500, 500, 500, 1000, 1000, 500, 500, 500, 500, 500, 500])

# %%
for m in range(len(FREQUENCIES)):
    winsound.Beep(FREQUENCIES[m],DURATION[m])

# %%
FREQUENCIES.index(int(f))
# Out:
# 4

# %%
plt.figure(figsize = [20,5])
plt.imshow(section_half)   
plt.plot(CX,, 'r.')

# %%
CX, CY, notes_freq
# Out:
# ([201,
#   156,
#   792,
#   744,
#   678,
#   633,
#   588,
#   543,
#   297,
#   251,
#   406,
#   361,
#   453.5,
#   838.5,
#   453.5,
#   838.5],
#  [113,
#   113,
#   109,
#   109,
#   105,
#   105,
#   101,
#   101,
#   97,
#   97,
#   92,
#   92,
#   98.0,
#   114.0,
#   98.0,
#   114.0],
#  [213,
#   213,
#   392,
#   392,
#   448,
#   448,
#   347,
#   347,
#   302,
#   302,
#   258,
#   258,
#   381,
#   201,
#   381,
#   201])

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-100-b294d1cbc3a8> in <module>()
# ----> 1 y_half.index(98)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'index'

# %%
notes_freq
# Out:
# [213, 213, 392, 392, 448, 448, 347, 347, 302, 302, 258, 258, 381, 201]

# %%
twinkle = cv2.imread("Twinkle_Twinkle_Sheet_Music.png")
twinkle = cv2.cvtColor(twinkle, cv2.COLOR_BGR2GRAY)

s = 0

# %%
w,h
# Out:
# (17, 12)

# %%
loc
# Out:
# (array([ 92,  92,  92, 108], dtype=int64),
#  array([444, 445, 446, 830], dtype=int64))

# %%
loc
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
loc[0], loc[1]
# Out:
# (array([ 92,  92,  92, 108, 222, 222, 328, 329, 345], dtype=int64),
#  array([444, 445, 446, 830, 385, 820, 388, 387, 817], dtype=int64))

# %%
s = 2
section = image[s*shape[0]//sections:(s+1)*shape[0]//3,:]
ret,thresh = cv2.threshold(section.astype('uint8'),0,255,1)
contours,hierarchy = cv2.findContours(thresh, 1, 2)
CX, CY = [],[]
for j in range(len(contours[:])):
    cnt = contours[j]
    M = cv2.moments(cnt)
    cx = int(M['m10']/M['m00'])
    cy = int(M['m01']/M['m00'])
    CX.append(cx)
    CY.append(cy)

#     plt.figure(figsize = [20,2])
#     plt.imshow(thresh)
#     plt.plot(CX, CY, 'r.')
#     plt.show()

indices, CX_sorted= zip(*sorted(enumerate(CX), key=itemgetter(1)))
CY_sorted = []
for z in indices:
    CY_sorted.append(CY[z])
    Y_COORD.append(CY[z]+s*shape[0]//sections)
    X_COORD.append(CX[z])


size1 = 100
s1 = np.zeros(shape=[size1,size1])
s1[size1//2,:] = 1

staff = mp.dilation(twinkle[:,:,0],s1)
staff_sec = staff[s*shape[0]//sections:(s+1)*shape[0]//sections,:]


y = np.where(staff_sec[:,500] < 1)[0]
Y = []
for k in range(1,len(y)+1):
    if np.abs(y[k-2]-y[k-1]) > 2:
        Y.append(y[k-1])

# %%
y, Y
# Out:
# (array([48, 56, 57, 64, 65, 72, 73, 81], dtype=int64), [48, 56, 64, 72, 81])

# %%
X_calib, Y_calib = [],[]

for j in range(len(contours[:])):
    cnt = contours[j]
    M = cv2.moments(cnt)
    cx = int(M['m10']//M['m00'])
    cy = int(M['m01']//M['m00'])
    X_calib.append(cx)
    Y_calib.append(cy)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-214-28d4b4dbc57d> in <module>()
#       4     cnt = contours[j]
#       5     M = cv2.moments(cnt)
# ----> 6     cx = int(M['m10']//M['m00'])
#       7     cy = int(M['m01']//M['m00'])
#       8     X_calib.append(cx)
#
# ZeroDivisionError: float divmod()

# %%
size1 = 6
kernel_1 = np.zeros(shape=[size1,size1])
kernel_1[size1//2,:] = 1

size2 = 11
kernel_2 = np.zeros(shape=[size2,size2])
kernel_2[:, size2//2] = 1

plt.subplot(1,2,1)
plt.imshow(kernel_1)
plt.subplot(1,2,2)
plt.imshow(kernel_2)

a = mp.dilation(twinkle, kernel_2)
#a = mp.erosion(a,s2/10)
b = mp.dilation(a, kernel_1)
c = mp.erosion(b,s2)

#threshhold = 125
#c[c<threshhold] = 0
plt.figure(figsize = [10,20])
plt.imshow(a)
plt.show()
plt.figure(figsize = [10,20])
plt.imshow(b)
plt.show()
plt.figure(figsize = [10,20])
plt.imshow(c)
plt.show()

# %%
ret,thresh = cv2.threshold(staff_sec.astype('uint8'),0,255,1)
contours,hierarchy = cv2.findContours(thresh, 1, 2)
X_calib, Y_calib = [],[]

for j in range(len(contours[:])):
    cnt = contours[j]
    M = cv2.moments(cnt)
    cx = int(M['m10']//M['m00'])
    cy = int(M['m01']//M['m00'])
    X_calib.append(cx)
    Y_calib.append(cy)
    
plt.figure(figsize = [20,10])
plt.imshow(staff_sec)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-182-c9ac3c1d8c8f> in <module>()
#       6     cnt = contours[j]
#       7     M = cv2.moments(cnt)
# ----> 8     cx = int(M['m10']//M['m00'])
#       9     cy = int(M['m01']//M['m00'])
#      10     X_calib.append(cx)
#
# ZeroDivisionError: float divmod()

# %%
len(contours[:])
# Out:
# 5

# %%
cnt = contours[5]
M = cv2.moments(cnt)
#cx = int(M['m10']/M['m00'])
#cy = int(M['m01']/M['m00'])
#cx, cy
M
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-176-ceef8fd19034> in <module>()
# ----> 1 cnt = contours[5]
#       2 M = cv2.moments(cnt)
#       3 #cx = int(M['m10']/M['m00'])
#       4 #cy = int(M['m01']/M['m00'])
#       5 #cx, cy
#
# IndexError: list index out of range

# %%
M
# Out:
# {'m00': 0.0,
#  'm01': 0.0,
#  'm02': 0.0,
#  'm03': 0.0,
#  'm10': 0.0,
#  'm11': 0.0,
#  'm12': 0.0,
#  'm20': 0.0,
#  'm21': 0.0,
#  'm30': 0.0,
#  'mu02': 0.0,
#  'mu03': 0.0,
#  'mu11': 0.0,
#  'mu12': 0.0,
#  'mu20': 0.0,
#  'mu21': 0.0,
#  'mu30': 0.0,
#  'nu02': 0.0,
#  'nu03': 0.0,
#  'nu11': 0.0,
#  'nu12': 0.0,
#  'nu20': 0.0,
#  'nu21': 0.0,
#  'nu30': 0.0}

# %%
plt.figure(figsize = [20,10])
plt.imshow(staff_sec)

# %%
Y_calib
# Out:
# [104, 96, 87, 79, 71]

# %%
freq = [698, 587, 494, 392, 330]

z1 = np.polyfit(pix1, freq, 1)
p1 = np.poly1d(z1)

plt.plot(pix1, freq, 'ro')
plt.plot(pix1, p1(pix1), 'k-')

def pix_to_freq_1(pix):
    return pix*p1[1] + p1[0]
# Out:
# [490, 490, 490, 490, 490]

# %%
plt.figure(figsize = [20,10])

A = []
CX, CY = [],[]
for i in range(len(contours[:])):
    cnt = contours[i]
    area = cv2.contourArea(cnt)
    M = cv2.moments(cnt)
    cx = int(M['m10']/M['m00'])
    cy = int(M['m01']/M['m00'])
    A.append(area)
    CX.append(cx)
    CY.append(cy)

plt.imshow(notes)
plt.plot(CX, CY, 'ro')

# %%
plt.figure(figsize = [20,10])

size1 = 50
s1 = np.zeros(shape=[size1,size1])
s1[size1//2,:] = 1

staff = mp.dilation(twinkle[:,:,0],s1)

ret_s,thresh_s = cv2.threshold(staff.astype('uint8'),0,1,1)
contours_s,hierarchy_s = cv2.findContours(thresh_s, 1, 4)
plt.imshow(thresh_s)

# %%
plt.plot(thresh_s[:,500])
np.where(thresh_s[:,500]==1)
# Out:
# (array([ 71,  72,  79,  80,  87,  88,  96,  97, 104, 105, 189, 190, 198,
#         206, 207, 214, 215, 222, 223, 308, 316, 317, 324, 325, 332, 333,
#         341], dtype=int64),)

# %%
#1st Staff
# [F5,D5,B5,G4,E4]
pix1 = [71, 79, 87, 96, 104]
freq = [698, 587, 494, 392, 330]

z1 = np.polyfit(pix1, freq, 1)
p1 = np.poly1d(z1)

plt.plot(pix1, freq, 'ro')
plt.plot(pix1, p1(pix1), 'k-')

def pix_to_freq_1(pix):
    return pix*p1[1] + p1[0]

# %%
f_1 = []
for i in range(8):
    f_1.append(int(pix_to_freq_1(np.flip(CY))[i]))
f_1

# %%
size1 = 9
s1 = np.zeros(shape=[size1,size1])
s1[size1//2,:] = 1

size2 = 5
s2 = np.zeros(shape=[size2,size2])
s2[:, size2//2] = 1

plt.subplot(1,2,1)
plt.imshow(s1)
plt2subplot(1,2,2)
plt.imshow(s2)

# %%
a = mp.dilation(notes, s1)
b = mp.dilation(a, s2)
c = mp.erosion(b,s3[:,0])
#a = mp.dilation(notes, s2)
#c = mp.erosion(a,s4[:,:,0])

threshhold = 200
c[c<threshhold] = 0
plt.figure(figsize = [10,20])
plt.imshow(a)
# plt.figure(figsize = [10,20])
# plt.imshow(b)
# plt.show()
plt.figure(figsize = [10,20])
plt.imshow(c)
plt.show()

# %%
d = cv2.Canny(c,threshhold,255)
plt.figure(figsize = [20,20])
plt.imshow(d)

# %%
plt.figure(figsize = [20,20])
ret,thresh = cv2.threshold(c,100, 255,0)
contours,hierarchy = cv2.findContours(thresh, 1, 2)
plt.imshow(thresh)

# %%
notes.dtype
